# %%
import numpy as np
import pandas as pd

df1=pd.read_csv('df1.csv',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01 -0.914725  0.194963  0.700119  0.366586
# 2000-01-02 -0.104786 -0.892622 -0.467943  0.491949
# 2000-01-03  0.520284  0.413954 -0.103613 -0.701114
# 2000-01-04  0.685179 -0.779894  0.055239  0.358203
# 2000-01-05 -0.718142  0.999913 -0.864109 -0.215179

# %%
len(df1)
# Out:
# 1000

# %%
df1.describe()
# Out:
#                  A            B            C            D
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.018268     0.000274    -0.010674     0.006291
# std       0.581500     0.571786     0.580791     0.564949
# min      -0.999688    -0.999907    -0.999635    -0.999921
# 25%      -0.526341    -0.473140    -0.521423    -0.471863
# 50%      -0.024464     0.015954     0.002271     0.011909
# 75%       0.495790     0.482021     0.501675     0.482526
# max       0.995304     0.999913     0.998856     0.997273

# %%
df2=pd.read_csv('df2.csv')

# %%
df2.describe()
# Out:
#                a          b          c          d
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.487508   0.502409   0.619045   0.457710
# std     0.230146   0.293368   0.274004   0.270069
# min     0.308695   0.095065   0.301105   0.063166
# 25%     0.358085   0.220363   0.382781   0.228026
# 50%     0.390300   0.573630   0.551122   0.528471
# 75%     0.455876   0.711458   0.895098   0.637595
# max     0.945508   0.951897   0.971839   0.862894

# %%
df1['A'].plot.hist()

# %%
df1['B'].plot.hist()

# %%
df1['A'].plot.hist(edgecolor='k')

# %%
df1['A'].plot.hist(edgecolor='k').autoscale(enable=True,axis='both',tight=True)

# %%
df1['A'].plot.hist(edgecolor='k',color='g').autoscale(enable=True,axis='both',tight=True)

# %%
df1['A'].plot.hist(edgecolor='k',color='g',bins=20).autoscale(enable=True,axis='both',tight=True)

# %%
df1['A'].plot.hist(edgecolor='k',color='g',bins=100).autoscale(enable=True,axis='both',tight=True)

# %%
df1['A'].hist()

# %%
df1[['A','B']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9cd59ad850>,
# ...
#       dtype=object)

# %%
df2.plot.bar()

# %%
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.308695  0.533459  0.301105  0.735057  y
# 1  0.945508  0.751815  0.971839  0.542986  z
# 2  0.350826  0.700512  0.897065  0.564248  z
# 3  0.400322  0.171575  0.889197  0.205580  x
# 4  0.379860  0.951897  0.363855  0.131811  y

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.barh()

# %%
df2.plot.barh(stacked=True)

# %%
df2.plot.line(y='a')

# %%
df2.plot.line(y='a', figsize=(12,3))

# %%
df2.plot.line(y='a', figsize=(12,3), lw=15)

# %%
df2.plot.line(y=['a','b','c','d'], figsize=(12,3), lw=5)

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.3)

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B',alpha=0.3)

# %%
df1.plot.scatter(x='A',y='B',alpha=0.3, c='r')

# %%
df1.plot.scatter(x='A',y='B',cmap='Oranges',alpha=0.3, c='b')

# %%
df1.plot.scatter(x='A',y='B',alpha=0.3,c='r',s=df1['C']*150)

# %%
df2.boxplot()

# %%
df2.describe()
# Out:
#                a          b          c          d
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.487508   0.502409   0.619045   0.457710
# std     0.230146   0.293368   0.274004   0.270069
# min     0.308695   0.095065   0.301105   0.063166
# 25%     0.358085   0.220363   0.382781   0.228026
# 50%     0.390300   0.573630   0.551122   0.528471
# 75%     0.455876   0.711458   0.895098   0.637595
# max     0.945508   0.951897   0.971839   0.862894

# %%
df2[['b','e']].boxplot(by='e',grid=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
df2['a'].plot.kde()

# %%
df1.plot.kde()

# %%
df1['A'].plot.kde()

# %%
df1[['A','B']].plot.kde()

# %%
df2.plot.kde()

# %%
df=pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])
df
# Out:
#             a         b
# 0   -2.111696  0.258904
# 1   -1.030825 -0.157600
# 2    0.675409 -0.930964
# 3   -0.095261 -0.472055
# 4   -0.263663  0.744681
# ..        ...       ...
# 995 -1.857390  0.089774
# 996 -0.253260  0.938687
# 997 -0.893210 -0.644665
# 998 -0.596807 -0.532378
# 999 -0.205220  1.012188
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='a',y='b')

# %%
df.plot.hexbin(x='a',y='b',gridsize=20)

# %%
df2.plot.pie(y='a')

# %%
df2[['b','e']].boxplot(by='e',grid=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
df2[['b','e']].boxplot(grid=False)

# %%
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.308695  0.533459  0.301105  0.735057  y
# 1  0.945508  0.751815  0.971839  0.542986  z
# 2  0.350826  0.700512  0.897065  0.564248  z
# 3  0.400322  0.171575  0.889197  0.205580  x
# 4  0.379860  0.951897  0.363855  0.131811  y
