# %%
# !pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from mtcnn) (2.12.0)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from mtcnn) (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.23.5)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1

# %%
# !mkdir images

# %%
import mtcnn
# print version
print(mtcnn.__version__)
# Out:
# 0.1.0

# %%
from mtcnn.mtcnn import MTCNN
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load image from file
pixels = plt.imread('./images/demo.jpeg')

# %%
detector = MTCNN()
# detect faces in the image
results = detector.detect_faces(pixels)
# Out:
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 29/29 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 39ms/step

# %%
results
# Out:
# [{'box': [210, 82, 112, 151],
#   'confidence': 0.9999949336051941,
#   'keypoints': {'left_eye': (250, 141),
#    'right_eye': (298, 155),
#    'nose': (272, 178),
#    'mouth_left': (240, 192),
#    'mouth_right': (281, 204)}},
#  {'box': [434, 367, 105, 131],
#   'confidence': 0.9999949336051941,
#   'keypoints': {'left_eye': (472, 412),
#    'right_eye': (518, 424),
#    'nose': (493, 450),
#    'mouth_left': (459, 455),
#    'mouth_right': (506, 469)}},
#  {'box': [781, 140, 110, 148],
#   'confidence': 0.9999688267707825,
#   'keypoints': {'left_eye': (826, 204),
#    'right_eye': (873, 211),
#    'nose': (853, 240),
#    'mouth_left': (824, 255),
#    'mouth_right': (862, 260)}},
#  {'box': [611, 322, 105, 145],
#   'confidence': 0.9999648928642273,
#   'keypoints': {'left_eye': (638, 376),
#    'right_eye': (685, 384),
#    'nose': (654, 412),
#    'mouth_left': (631, 420),
#    'mouth_right': (679, 430)}},
#  {'box': [374, 67, 89, 129],
#   'confidence': 0.9997633099555969,
#   'keypoints': {'left_eye': (393, 118),
#    'right_eye': (440, 119),
#    'nose': (413, 148),
#    'mouth_left': (394, 160),
#    'mouth_right': (439, 163)}},
#  {'box': [599, 48, 102, 145],
#   'confidence': 0.9964742660522461,
#   'keypoints': {'left_eye': (626, 105),
#    'right_eye': (674, 104),
#    'nose': (652, 141),
#    'mouth_left': (632, 158),
#    'mouth_right': (676, 155)}}]

# %%
# draw an image with detected objects
def draw_facebox(filename, result_list):
    # load the image
    data = plt.imread(filename)
    # plot the image
    plt.imshow(data)
    # get the context for drawing boxes
    ax = plt.gca()
    # plot each box
    for result in result_list:
        # get coordinates
        x, y, width, height = result['box']
        # create the shape
        rect = plt.Rectangle((x, y), width, height, fill=False, color='green')
        # draw the box
        ax.add_patch(rect)
        # show the plot
    plt.show()

# %%
draw_facebox('./images/demo.jpeg', results)

# %%
# draw an image with detected objects
def draw_facebox_and_keypoints(filename, result_list):
    # load the image
    data = plt.imread(filename)
    # plot the image
    plt.imshow(data)
    # get the context for drawing boxes
    ax = plt.gca()
    # plot each box
    for result in result_list:
        # get coordinates
        x, y, width, height = result['box']
        # create the shape
        rect = plt.Rectangle((x, y), width, height,fill=False, color='orange')
        # draw the box
        ax.add_patch(rect)
        # draw the dots
        for key, value in result['keypoints'].items():
            # create and draw dot
            dot = plt.Circle(value, radius=1, color='red')
            ax.add_patch(dot)
            # show the plot
    plt.show()# filename = 'test1.jpg' # filename is defined above, otherwise uncomment

# %%
draw_facebox_and_keypoints('./images/demo.jpeg', results)
